# %%
import os
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_community.document_loaders import WebBaseLoader
from langchain.embeddings import OllamaEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_core.prompts import ChatPromptTemplate
from langchain.chains import create_retrieval_chain
from langchain_community.vectorstores import FAISS
import time
from dotenv import load_dotenv
import bs4
from langchain_groq import ChatGroq
from langchain_community.document_loaders import PyPDFLoader

load_dotenv()
from langchain_community.document_loaders import PyPDFDirectoryLoader
## load the Groq API key
groq_api_key = os.environ['GROQ_API_KEY']

# %%
from langchain_community.embeddings import HuggingFaceBgeEmbeddings

model_name = "BAAI/bge-large-en"
model_kwargs = {"device": "cpu"}
encode_kwargs = {"normalize_embeddings": True}
hf = HuggingFaceBgeEmbeddings(
    model_name=model_name, model_kwargs=model_kwargs, encode_kwargs=encode_kwargs
)
# Out:
# c:\Users\Ritesh Kapoor\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
from bs4 import BeautifulSoup as Soup
from langchain_community.document_loaders.recursive_url_loader import RecursiveUrlLoader

# %%
embeddings=hf


from langchain_community.document_loaders import PyPDFLoader

embeddings=hf
url = "https://www.datacamp.com/cheat-sheet/getting-started-with-python-cheat-sheet"
loader = RecursiveUrlLoader(
url=url, max_depth=20, extractor=lambda x: Soup(x, "html.parser").text
    )
docs = loader.load()


print(docs)
text_splitter=RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=250) 
final_documents=text_splitter.split_documents(docs) 
vectors=FAISS.from_documents(final_documents,embeddings)
# Out:
# [Document(page_content='          25   SCHOLARSHIPS / TUITIO N FREESHIPS FOR THE SESSION 202 4-25 \n      25.1  MERIT SCHOLARSHIP – BE/BTech STUDENTS  \nMerit Scholarships  to the first year UG students will be awarded on the basis of All  India Rank                          \n(AIR) in JEE Mains -2024 for the year 202 4-25 with the criteria mentioned against each scholarship . \n \nSr. \nNo. Name of the Scholarship  Criteria for First Year  Number  Value of \nScholar  \nship Criteria from 2nd year and \nonwards  \n1 MERIT SCHOLARSHIPS -I  \nAggregate Marks*  \n> 95% at 10+2 level.  \n \nFirst 50  students \nirrespective of branch \non the basis of AIR of \nJEE Main -2024. \n 50 TF + DF \nwaive \noff Minimum 8.50 CGPA in all the \npreceding semester(s) and \nshould not have any backlog  \nin the year of consideration \nand must have passed all the \ncourses offered in the \nsemester(s) prio r to the year \nof consideration.  \n \nThe merit Scholarship -I & II will \nbe awarded on the 
# ...

# %%
llm=ChatGroq(temperature=0, model_name="Llama3-70b-8192")
# Model: Llama3-70b-8192 mixtral-8x7b-32768

prompt=ChatPromptTemplate.from_template(
    """
    you are a coding test platform.
    I have give you a context of python documentation. 
    You need to ask questions only on python language  <context>
    {context}
    <context>
    Questions:{input}
    """
    )
document_chain = create_stuff_documents_chain(llm, prompt)
retriever = vectors.as_retriever()
retrieval_chain = create_retrieval_chain(retriever, document_chain)

# %%
response=retrieval_chain.invoke({"input":f'create 10 random challenging {}objective type question on python language generate only 3 options out of which only 1 is correct. tell correct option     '})
print(response['answer'])
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 response=retrieval_chain.invoke({"input":"explain Guru Harkrishan Educational Society Scholarship"})
#       3 print(response['answer'])
#
# File c:\Users\Ritesh Kapoor\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\runnables\base.py:4444, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    4438 def invoke(
#    4439     self,
#    4440     input: Input,
#    4441     config: Optional[RunnableConfig] = None,
#    4442     **kwargs: Optional[Any],
#    4443 ) -> Output:
# -> 4444     return self.bound.invoke(
#    4445         input,
#    4446         self._merge_configs(config),
#    4447         **{**self.kwargs, **kwargs},
#    4448     )
#
# ...

# %%
from llama_index.llms.groq import Groq
from dotenv import load_dotenv
import os 
load_dotenv()

## load the Groq API key
groq_api_key = os.environ['GROQ_API_KEY']
llm = Groq(model="llama3-70b-8192", api_key=groq_api_key)

# %%
from llama_index.core.llms import ChatMessage

messages = [
    ChatMessage(
        role="system", content="you are an intelligent coding assistant "
    ),
    ChatMessage(role="user", content="give code for uples in python  "),
]
resp = llm.chat(messages)
print(resp)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[35], line 9
#       1 from llama_index.core.llms import ChatMessage
#       3 messages = [
#       4     ChatMessage(
#       5         role="system", content="you are an intelligent coding assistant "
#       6     ),
#       7     ChatMessage(role="user", content="give code for uples in python  "),
#       8 ]
# ----> 9 resp = llm.chat(messages)
#      10 print(resp)
#
# File c:\Users\Ritesh Kapoor\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:223, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     219 self.span_enter(
#     220     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     221 )
#     222 try:
# --> 223     result = func(*args, **kwargs)
#     224 except BaseException as e:
# ...
